# %%
import pandas as pd
import os

# %%
path = r'C:\Users\JinXuanchen\Documents\RandLA-Net_demo\ori_data\Area_2\part_1\Annotations'
files = os.listdir(path)
txts = []
classnames = []
label_list = []
points_list = []
labels = pd.DataFrame()
points = pd.DataFrame()
total_length = 0

# %%
# 查找各个类的.txt文件
for file in files:
    if file[0:2] != '._':
        element = file.split('.')
        classnames.append(element[0].split('_'))

# %%
for name in classnames:
    
    if name[0] == "barrier":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('1')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')    
    
    elif name[0] == "car":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('2')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "cone":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('3')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "handrail":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('4')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "human":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('5')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "light":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('6')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "manhole":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('7')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "midline":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('8')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "motor":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('9')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "ridge":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('10')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "road":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):
            label_list.append('11')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "roadedge":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('12')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "sign":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('13')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "tree":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('14')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "walkway":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('15')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "building":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('16')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "slope":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('17')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "lawn":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('18')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "wall":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('19')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
# Out:
# barrier_1  completed
# barrier_2  completed
# barrier_3  completed
# barrier_4  completed
# barrier_5  completed
# barrier_6  completed
# barrier_7  completed
# building_1  completed
# building_2  completed
# building_3  completed
# building_4  completed
# building_5  completed
# building_6  completed
# car_1  completed
# car_2  completed
# cone_000001  completed
# cone_000002  completed
# cone_000003  completed
# cone_000004  completed
# cone_000005  completed
# cone_000006  completed
# cone_7  completed
# handrail_000000  completed
# handrail_000001  completed
# handrail_000002  completed
# handrail_000003  completed
# handrail_000004  completed
# handrail_000005  completed
# handrail_000006  completed
# handrail_000007  completed
# handrail_000008  completed
# handrail_000009  completed
# handrail_000010  completed
# handrail_000011  completed
# handrail_000012  completed
# handrail_000013  completed
# handrail_000014  completed
# handrail_000015  completed
# ...

# %% [markdown]
# barrier
# car
# cone
# handrail
# human
# light
# manhole
# midline
# motor
# ridge
# road
# roadedge
# sign
# tree
# walkway
# wall

# %%
labels = pd.DataFrame(label_list)
points = pd.DataFrame(points_list)

# %%
labels.to_csv(r'C:\Users\JinXuanchen\Documents\RandLA-Net_demo\semantic3d\original_data\Area_2.labels',index = False, header= None)

# %%
points = points[[0,1,2,6,3,4,5]]
points.to_csv(r'C:\Users\JinXuanchen\Documents\RandLA-Net_demo\semantic3d\original_data\Area_2.txt', index=False, header=None,sep=' ')
