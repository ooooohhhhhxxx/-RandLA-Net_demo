# %%
import pandas as pd
import os

# %%
path = '/Users/jinxuanchen/Desktop/all/Area_1/part_1/Annotations'
files = os.listdir(path)
txts = []
classnames = []
label_list = []
points_list = []
labels = pd.DataFrame()
points = pd.DataFrame()
total_length = 0

# %%
# 查找各个类的.txt文件
for file in files:
    if file[0:2] != '._':
        element = file.split('.')
        classnames.append(element[0].split('_'))

# %%
for name in classnames:
    
    if name[0] == "barrier":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('1')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')    
    
    elif name[0] == "car":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('2')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "cone":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('3')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "handrail":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('4')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "human":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('5')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "light":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('6')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "manhole":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('7')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "midline":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('8')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "motor":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('9')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "ridge":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('10')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "road":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):
            label_list.append('11')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "roadedge":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )

        for i in range(len(pc[0])):

            label_list.append('12')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
    
    elif name[0] == "sign":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('13')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "tree":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('14')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')

    elif name[0] == "walkway":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('15')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
        
    elif name[0] == "sign":
        pc = pd.read_csv(
            path + "/" + name[0] + "_" + name[1] + ".txt", sep=" ", header=None
        )
        for i in range(len(pc[0])):
            label_list.append('16')
            point_dict = {}
            point_dict.update(pc.iloc[i])
            points_list.append(point_dict)
        print(name[0]+'_'+name[1],' completed')
# Out:
# light_4  completed
# manhole_000022  completed
# tree_2  completed
# walkway_17  completed
# ridge_7  completed
# sign_49  completed
# sign_48  completed
# ridge_6  completed
# walkway_16  completed
# tree_3  completed
# manhole_000023  completed
# walkway_3  completed
# light_5  completed
# walkway_1  completed
# light_7  completed
# manhole_000021  completed
# manhole_000009  completed
# tree_1  completed
# walkway_14  completed
# ridge_4  completed
# ridge_5  completed
# walkway_15  completed
# manhole_000008  completed
# manhole_000020  completed
# light_6  completed
# car_10  completed
# roadedge_8  completed
# walkway_4  completed
# light_2  completed
# manhole_000018  completed
# walkway_000002  completed
# manhole_000024  completed
# tree_4  completed
# walkway_11  completed
# car_9  completed
# ridge_1  completed
# roadedge_18  completed
# car_8  completed
# walkway_10  completed
# tree_5  completed
# manhole_000025  completed
# manhole_000019  completed
# light_3  completed
# walkway_5  completed
# roadedge_9  completed
# light_1  completed
# walkway_7  completed
# tree_7  completed
# walkway_12  completed
# ridge_2  completed
# ridge_3  completed
# walkway_13  completed
# tree_6  completed
# manhole_000026  completed
# walkway_6  completed
# tree_10  completed
# handrail_22  completed
# motor_3  completed
# sign_1  completed
# cone_6  completed
# road_6  completed
# sign_16  completed
# sign_17  completed
# handrail_7  completed
# road_7  completed
# cone_7  completed
# handrail_23  completed
# tree_11  completed
# tree_13  completed
# handrail_21  completed
# sign_2  completed
# road_5  completed
# cone_5  completed
# sign_29  completed
# sign_15  completed
# sign_14  completed
# sign_28  completed
# cone_4  completed
# road_4  completed
# sign_3  completed
# handrail_20  completed
# tree_12  completed
# tree_16  completed
# handrail_18  completed
# midline_000001  completed
# handrail_24  completed
# motor_5  completed
# manhole_27  completed
# sign_7  completed
# manhole_33  completed
# sign_10  completed
# sign_38  completed
# sign_39  completed
# sign_11  completed
# manhole_32  completed
# sign_6  completed
# cone_1  completed
# road_1  completed
# handrail_25  completed
# motor_4  completed
# handrail_19  completed
# tree_17  completed
# tree_15  completed
# midline_000002  completed
# motor_6  completed
# handrail_27  completed
# cone_3  completed
# road_3  completed
# sign_4  completed
# manhole_30  completed
# sign_13  completed
# sign_12  completed
# manhole_31  completed
# sign_5  completed
# road_2  completed
# cone_2  completed
# motor_7  completed
# handrail_26  completed
# midline_000003  completed
# tree_14  completed
# tree_19  completed
# road_15  completed
# handrail_17  completed
# manhole_28  completed
# sign_8  completed
# sign_37  completed
# sign_23  completed
# sign_22  completed
# sign_36  completed
# sign_9  completed
# manhole_29  completed
# barrier_1  completed
# handrail_16  completed
# road_14  completed
# tree_18  completed
# handrail_14  completed
# handrail_28  completed
# barrier_3  completed
# sign_20  completed
# sign_34  completed
# sign_35  completed
# sign_21  completed
# barrier_2  completed
# motor_8  completed
# handrail_15  completed
# tree_23  completed
# road_13  completed
# handrail_11  completed
# road_9  completed
# barrier_6  completed
# sign_25  completed
# handrail_9  completed
# sign_31  completed
# sign_19  completed
# sign_18  completed
# sign_30  completed
# handrail_8  completed
# sign_24  completed
# road_8  completed
# cone_8  completed
# handrail_10  completed
# road_12  completed
# tree_22  completed
# tree_20  completed
# road_10  completed
# handrail_12  completed
# barrier_5  completed
# sign_32  completed
# sign_26  completed
# sign_27  completed
# sign_33  completed
# barrier_4  completed
# handrail_13  completed
# road_11  completed
# tree_21  completed
# roadedge_7  completed
# handrail_000003  completed
# manhole_000003  completed
# manhole_000017  completed
# light_11  completed
# car_6  completed
# roadedge_17  completed
# sign_54  completed
# sign_40  completed
# sign_41  completed
# sign_55  completed
# roadedge_16  completed
# car_7  completed
# light_10  completed
# manhole_000016  completed
# manhole_000002  completed
# motor_000002  completed
# handrail_000002  completed
# roadedge_6  completed
# roadedge_4  completed
# walkway_8  completed
# manhole_000014  completed
# manhole_000000  completed
# tree_8  completed
# light_12  completed
# car_5  completed
# roadedge_14  completed
# sign_43  completed
# sign_56  completed
# sign_42  completed
# roadedge_15  completed
# car_4  completed
# light_13  completed
# tree_9  completed
# manhole_000001  completed
# manhole_000015  completed
# walkway_9  completed
# motor_000001  completed
# handrail_000001  completed
# roadedge_5  completed
# roadedge_1  completed
# handrail_000005  completed
# manhole_000011  completed
# manhole_000005  completed
# human_3  completed
# walkway_18  completed
# roadedge_11  completed
# sign_46  completed
# sign_52  completed
# sign_53  completed
# sign_47  completed
# roadedge_10  completed
# light_16  completed
# car_1  completed
# human_2  completed
# manhole_000004  completed
# manhole_000010  completed
# handrail_000004  completed
# roadedge_2  completed
# light_8  completed
# handrail_000006  completed
# manhole_000006  completed
# manhole_000012  completed
# car_3  completed
# light_14  completed
# roadedge_12  completed
# sign_51  completed
# sign_45  completed
# sign_44  completed
# sign_50  completed
# roadedge_13  completed
# light_15  completed
# car_2  completed
# human_1  completed
# manhole_000013  completed
# manhole_000007  completed
# light_9  completed
# roadedge_3  completed

# %% [markdown]
# barrier
# car
# cone
# handrail
# human
# light
# manhole
# midline
# motor
# ridge
# road
# roadedge
# sign
# tree
# walkway
# wall

# %%
labels = pd.DataFrame(label_list)
points = pd.DataFrame(points_list)

# %%
labels.to_csv('/Users/jinxuanchen/Desktop/test/Area_1.labels',index = False, header= None)

# %%
points = points[[0,1,2,6,3,4,5]]
points.to_csv('/Users/jinxuanchen/Desktop/test/Area_1.txt', index=False, header=None,sep=' ')
